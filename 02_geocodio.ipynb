# %% [markdown]
# # Geocodio
#
# 1. Create a Geocodio account!
#
# 2. Upload your `intersections.csv` file to Geocodio and follow the instructions: https://www.geocod.io/upload/
#
# 3. import pandas as pdDownload the file into your outputs folder.

# %%
import pandas as pd

# %% [markdown]
# ## Let's import the file Geocodio gave you

# %%
geocoded = pd.read_csv('outputs/intersections_geocodio_c6044031aa6c588cb00ad09b9cd26d716986be34.csv', dtype={'Zip': object})

# %%
geocoded.tail(3)
# Out:
#                                   intersection   Latitude   Longitude  \
# 830  W GERTRUDE AVE AND MAYA WAY, RICHMOND, CA  37.954196 -122.368020
# 831       BISSELL AVE AND 5TH ST, RICHMOND, CA  37.934066 -122.364707
# 832    S 20TH ST AND FLORIDA AVE, RICHMOND, CA  37.929440 -122.350301
#
#      Accuracy Score  Accuracy Type Number          Street  Unit Type  \
# 830             1.0  street_center    NaN  W Gertrude Ave        NaN
# 831             1.0   intersection    NaN          5th St        NaN
# 832             1.0   intersection    NaN     Florida Ave        NaN
#
#      Unit Number      City  ... Carrier Route ID Carrier Route Description  \
# 830          NaN  Richmond  ...              NaN                       NaN
# 831          NaN  Richmond  ...              NaN                       NaN
# 832          NaN  Richmond  ...              NaN                       NaN
#
#     Building or Firm Name Government Building Code  \
# ...

# %%
geocoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   intersection                            832 non-null    object
#  1   Latitude                                833 non-null    float64
#  2   Longitude                               833 non-null    float64
#  3   Accuracy Score                          833 non-null    float64
#  4   Accuracy Type                           832 non-null    object
#  5   Number                                  2 non-null      object
#  6   Street                                  764 non-null    object
#  7   Unit Type                               0 non-null      float64
#  8   Unit Number                             0 non-null      float64
#  9   City                                    832 non-null    object
# ...

# %%
geocoded.columns
# Out:
# Index(['intersection', 'Latitude', 'Longitude', 'Accuracy Score',
#        'Accuracy Type', 'Number', 'Street', 'Unit Type', 'Unit Number', 'City',
#        'State', 'County', 'Zip', 'Country', 'Source', 'ZIP+4 Range Start',
#        'ZIP+4 Range End (or blank if no range)', 'ZIP 9 Range Start',
#        'ZIP 9 Range End (or blank if no range)', 'Record Type Code',
#        'Record Type Description', 'Carrier Route ID',
#        'Carrier Route Description', 'Building or Firm Name',
#        'Government Building Code', 'Government Building Description',
#        'Facility Code', 'Facility Description', 'City Delivery?',
#        'Valid delivery area?', 'Exact Match?'],
#       dtype='object')

# %%
geocoded = geocoded[[
    'intersection', 'Latitude', 'Longitude', 'Accuracy Score',
    'Accuracy Type', 'City', 'State', 'County', 'Zip',
]].copy()
geocoded
# Out:
#                                        intersection   Latitude   Longitude  \
# 0           MACDONALD AVE AND 16TH ST, RICHMOND, CA  37.935600 -122.354250
# 1       RICHMOND PKWY AND LAKESIDE DR, RICHMOND, CA  37.989972 -122.328664
# 2         CUTTING BLVD AND S. 34TH ST, RICHMOND, CA  37.925244 -122.336718
# 3               29TH ST AND RHEEM AVE, RICHMOND, CA  37.949861 -122.338819
# 4       CUTTING BLVD AND HARBOUR WY S, RICHMOND, CA  37.925213 -122.360055
# ..                                              ...        ...         ...
# 828          GROVE ST AND BISSELL AVE, RICHMOND, CA  37.933341 -122.342634
# 829  WASHINGTON AVE AND TEWKSBURY AVE, RICHMOND, CA  37.928426 -122.385351
# 830       W GERTRUDE AVE AND MAYA WAY, RICHMOND, CA  37.954196 -122.368020
# 831            BISSELL AVE AND 5TH ST, RICHMOND, CA  37.934066 -122.364707
# 832         S 20TH ST AND FLORIDA AVE, RICHMOND, CA  37.929440 -122.350301
#
# ...

# %%
sorted(geocoded['Accuracy Score'].unique())
# Out:
# [0.0,
#  0.4,
#  0.42,
#  0.43,
#  0.5,
#  0.52,
#  0.56,
#  0.57,
#  0.6,
#  0.63,
#  0.64,
#  0.65,
#  0.66,
#  0.68,
#  0.69,
#  0.7,
#  0.71,
#  0.72,
#  0.73,
#  0.74,
#  0.76,
#  0.77,
#  0.78,
#  0.79,
#  0.8,
#  0.81,
#  0.82,
#  0.83,
#  0.84,
#  0.85,
#  0.86,
#  0.87,
#  0.88,
#  0.89,
#  0.9,
#  0.91,
#  0.92,
#  0.93,
#  0.94,
#  0.95,
#  0.96,
#  0.97,
#  0.98,
#  0.99,
#  1.0]

# %% [markdown]
# ## Merge it back to the original dataset

# %%
geocodable = pd.read_csv('outputs/geocodable.csv', parse_dates=['timestamp'])

# %%
geocodable.tail(3)
# Out:
#      report_number collision_date collision_time primary_road secondary_road  \
# 1599  2023-0010458     2023-11-24       23:00:00  BARRETT AVE        22ND ST
# 1600   2023-002675     2023-04-09       11:00:00      22ND ST  MACDONALD AVE
# 1601   2023-005654     2023-07-10       13:29:00    S 20TH ST    FLORIDA AVE
#
#      collision_day_of_week  number_of_parties primary_collision_factor  \
# 1599                Friday                NaN               Not Stated
# 1600                Sunday                NaN         Improper Turning
# 1601                Monday                NaN         Improper Turning
#
#       hit_and_run collision_type        involved_with       pedestrian_action  \
# 1599  Misdemeanor      Broadside  Other Motor Vehicle  No Pedestrian Involved
# 1600  Misdemeanor       Rear-End  Other Motor Vehicle  No Pedestrian Involved
# 1601           No     Hit Object         Fixed Object  No Pedestrian Involved
#
# ...

# %%
richmond_crashes_geocoded = pd.merge(geocodable, geocoded, how='left', on='intersection', validate='m:1')

# %%
richmond_crashes_geocoded
# Out:
#       report_number collision_date collision_time   primary_road  \
# 0     2020-00006039     2202-06-30       13:25:00  MACDONALD AVE
# 1      2020-0007656     2020-08-22       07:35:00  RICHMOND PKWY
# 2      2020-0008447     2020-09-02       20:08:00   CUTTING BLVD
# 3      2020-0011521     2020-12-22       07:04:00        29TH ST
# 4       2020-008872     2020-09-28       15:23:00   CUTTING BLVD
# ...             ...            ...            ...            ...
# 1597   2023-0010347     2023-11-20       00:50:00        15TH ST
# 1598   2023-0010393     2023-11-21       11:05:00    BISSELL AVE
# 1599   2023-0010458     2023-11-24       23:00:00    BARRETT AVE
# 1600    2023-002675     2023-04-09       11:00:00        22ND ST
# 1601    2023-005654     2023-07-10       13:29:00      S 20TH ST
#
#      secondary_road collision_day_of_week  number_of_parties  \
# 0           16TH ST             Wednesday                NaN
# ...

# %% [markdown]
# ## Export

# %%
richmond_crashes_geocoded.to_csv('outputs/richmond_crashes_geocoded.csv', index=False)
